# %% [markdown]
# # Comandos para crear proyecto Java con Maven

# %% [markdown]
# #### - Crear proyecto mvn:
#
# `mvn archetype:generate -DarchetypeArtifactId=maven-archetype-quickstart -DarchetypeVersion=1.5`
#
# GroupId: edu.teamrocket
#
# _______________________________

# %% [markdown]
# #### - Actualizar POM(cambiar nombre_proyecto, version..)
# _________

# %% [markdown]
# #### - Crear paquete proyecto con snapshot
#
# `mvn package`
#
# _____

# %% [markdown]
# #### - Comprobar si funciona el archivo snapshot
#
# `java -jar target/nombre_proyecto-1.0-SNAPSHOT.jar`
#
# _____

# %% [markdown]
# #### - Crear gitignore
# ____

# %% [markdown]
# #### - Iniciar repo github
#
# `git init`
# ____

# %% [markdown]
# #### - Comprobar test con maven
#
# `mvn test`
#
# `mvn test -Dtest=nombretest`
#
# ____

# %% [markdown]
# #### - Limpiar proyecto maven
#
# `mvn clean`
